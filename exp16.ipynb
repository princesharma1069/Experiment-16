# %% [markdown]
# Prince kumar sharma
#
# PRN:25070123086
#
# Aim: NLP Techniques on Text Data in python

# %%
# Tokenization
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize
text = "Natural language processing is interesting"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Natural', 'language', 'processing', 'is', 'interesting']

# %%
# sentence tokenizaion
from nltk.tokenize import sent_tokenize
text = " Python is easy. It is widely used in data science."
sentences = sent_tokenize(text)
print(sentences)
# Out:
# [' Python is easy.', 'It is widely used in data science.']

# %%
# stop word removal
#stop words such as is,the,and,in are removed
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

words = word_tokenize(text)
filtered_words = [w for w in words if w.lower() not in stop_words]
print(stop_words)
print(filtered_words)
# Out:
# {"shan't", 'couldn', 'up', 'where', 'during', 'him', 'hers', "aren't", 'these', 'own', "weren't", 'are', "i'm", 'not', "should've", 'until', 'mightn', 'after', 'can', 'if', 'my', 'myself', 'their', 'aren', 'and', 'o', 'above', 'needn', 'did', 'an', "doesn't", 'both', 'which', 'because', 'theirs', 'here', "don't", 'the', 'hasn', 'between', 'no', 'themselves', 'to', 'be', 'again', 'a', 'have', 'who', 'this', "mightn't", 'with', 'its', 'having', 'some', 'y', 'll', 'but', 's', 'being', 'once', "hadn't", 'more', "couldn't", 'doing', 'don', 'by', "they'll", 'each', "we've", "won't", 'd', 'into', 'i', 'just', 'in', 't', 'weren', 'what', 'shan', 'down', 'we', 'should', "she'll", 'too', "they've", 'at', 'such', 'same', 'your', 'further', "haven't", 'wouldn', "they're", 'how', 'so', 'that', 'when', 'ours', 'below', 'she', "she'd", 'few', 'yours', 'it', "needn't", 'our', 're', 'm', 'itself', "hasn't", 'under', "it'd", "they'd", 've', "we'll", 'there', 'am', 'wasn', 'didn', 'as', 'against', "he'll", 'me', 'ourselves', 'will', 'is', "you're", 'for', 'about', 'ain', 'were', "it's", 'while', "isn't", 'other', 'yourself', 'do', 'nor', 'than', 'them', 'his', "you've", 'they', 'only', "that'll", "you'll", 'why', 'then', 'does', 'most', 'off', 'haven', "i'd", "it'll", 'her', "mustn't", 'over', "we're", "i've", 'won', "you'd", "he's", 'you', "she's", 'whom', 'hadn', 'yourselves', "shouldn't", 'was', 'very', 'before', 'now', 'shouldn', "didn't", 'out', "we'd", 'isn', 'been', 'doesn', 'had', 'ma', 'of', 'any', 'all', 'himself', "wasn't", 'has', 'on', 'from', 'herself', 'those', "he'd", "i'll", "wouldn't", 'he', 'mustn', 'or', 'through'}
# ['Python', 'easy', '.', 'widely', 'used', 'data', 'science', '.']

# %%
# stemming
# stemming reduces words to their root form
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
words = ["playing", "studies", "running","gone","watched","coding"]
stemmed_words = [stemmer.stem(word) for word in words]
print(stemmed_words)
# Out:
# ['play', 'studi', 'run', 'gone', 'watch', 'code']

# %%
#part of speech (POS) Tagging
# POS tagging identifies grammatical roles of words
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import pos_tag

words = word_tokenize("Python is a powerful programming language")
pos_tags = pos_tag(words)
print(pos_tags)
# Out:
# [('Python', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('powerful', 'JJ'), ('programming', 'NN'), ('language', 'NN')]

# %%
from platform import freedesktop_os_release
from nltk.probability import FreqDist
words = word_tokenize(text)
freq_dist = FreqDist(words)
print(freq_dist)
# Out:
# <FreqDist with 10 samples and 12 outcomes>

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("writing"))
print(lemmatizer.lemmatize("studies"))
print(lemmatizer.lemmatize("best"))
print(lemmatizer.lemmatize("running"))
print(lemmatizer.lemmatize("coding"))
# Out:
# writing
# study
# best
# running
# coding
